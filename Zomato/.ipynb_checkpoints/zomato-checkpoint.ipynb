# %%
# Import BeautifulSoup and other requirements 
import pandas as pd
from bs4 import BeautifulSoup as bs
import bs4
import time
from splinter import Browser
import requests
from pprint import pprint
import config
from config import api_key
import json

# %%
base_url = "https://developers.zomato.com/api/v2.1/search?city_id=278"

targetCityid = input("enter the id")
header = {"User-agent": "curl/7.43.0", "Accept": "application/json", "user_key": "a22ef1379bcf801113252f8b81a8081a"}
# url = base_url + "apiKey=" + params['apiKey'];
response = requests.get(base_url, headers=header).json()
response
# Out:
# enter the id278
# {'results_found': 4618,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 16912903},
#     'apikey': 'a22ef1379bcf801113252f8b81a8081a',
#     'id': '16912903',
#     'name': "Hut's Hamburgers",
#     'url': 'https://www.zomato.com/austin/huts-hamburgers-downtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '807 W 6th Street, Austin 78703',
#      'locality': 'Downtown',
#      'city': 'Austin',
#      'city_id': 278,
#      'latitude': '30.2703694444',
#      'longitude': '-97.7510750000',
#      'zipcode': '78703',
#      'country_id': 216,
#      'locality_verbose': 'Downtown, Austin'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger',
#     'timings': '11 AM to 9:30 PM (Mon, Tue, Sun), 11 AM to 10 PM (Wed-Sat)',
#     'average_cost_for_two': 30,
#     'price_range': 2,
#     'currency': '$',
# ...

# %%
location = []
latitude = []
longitude = []


# base_url = "https://developers.zomato.com/api/v2.1/search?city_id=278"
# header = {"User-agent": "curl/7.43.0", "Accept": "application/json", "user_key": "a22ef1379bcf801113252f8b81a8081a"}

response = requests.get(base_url,headers=header)
zomato_json = response.json()
print(zomato_json)[location]
location.append(zomato_json['location'])
# for item in zomato_json:
#   location.append(zomato_json['latitude'])
# Out:
# {'results_found': 4618, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 16912903}, 'apikey': 'a22ef1379bcf801113252f8b81a8081a', 'id': '16912903', 'name': "Hut's Hamburgers", 'url': 'https://www.zomato.com/austin/huts-hamburgers-downtown?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '807 W 6th Street, Austin 78703', 'locality': 'Downtown', 'city': 'Austin', 'city_id': 278, 'latitude': '30.2703694444', 'longitude': '-97.7510750000', 'zipcode': '78703', 'country_id': 216, 'locality_verbose': 'Downtown, Austin'}, 'switch_to_order_menu': 0, 'cuisines': 'Burger', 'timings': '11 AM to 9:30 PM (Mon, Tue, Sun), 11 AM to 10 PM (Wed-Sat)', 'average_cost_for_two': 30, 'price_range': 2, 'currency': '$', 'highlights': ['Cash', 'Takeaway Available', 'Lunch', 'Serves Alcohol', 'Credit Card', 'Dinner', 'Casual Attire', 'Indoor Seating', 'Disabled Friendly', 'Vegetarian
# ...

# %%
zomato_json['restaurants'][20]['restaurant']['location']['longitude']
# Out:
# '-97.7838160000'

# %%
zomato_json['restaurants'][20]['restaurant']['location']['latitude']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-82ce1689b527> in <module>
# ----> 1 zomato_json['restaurants'][20]['restaurant']['location']['latitude']
#
# IndexError: list index out of range
